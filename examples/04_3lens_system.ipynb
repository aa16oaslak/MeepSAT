# %% [markdown]
# # 3-lens System using MeepSAT
#
# In this Tutorial, we are going to simulate a complex 3 lens system with all the possible components currently availabe in MeepSATs functionality. We will be simulating the system in low-frequency (LF) range i.e.,
